# %%
pip install -r requirements.txt
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/113.7 MB ? eta -:--:--
#    - -------------------------------------- 5.0/113.7 MB 25.2 MB/s eta 0:00:05
#    --- ------------------------------------ 11.0/113.7 MB 27.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 17.0/113.7 MB 27.5 MB/s eta 0:00:04
#    -------- ------------------------------- 22.8/113.7 MB 27.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 28.6/113.7 MB 27.9 MB/s eta 0:00:04
#    ------------ --------------------------- 34.9/113.7 MB 28.0 MB/s eta 0:00:03
#    -------------- ------------------------- 40.9/113.7 MB 28.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 46.9/113.7 MB 28.4 MB/s eta 0:00:03
#    ------------------ --------------------- 52.7/113.7 MB 28.4 MB/s eta 0:00:03
#    -------------------- ------------------- 58.5/113.7 MB 28.4 MB/s eta 0:00:02
# ...

# %%
python -m gcbf_plus.train_swarm \
    --num_agents 3 \
    --area_size 15.0 \
    --n_obs 8 \
    --num_steps 20 \
    --batch_size 4096 \
    --horizon 128 \
    --mini_batch_size 16384 \
    --n_epochs 4 \
    --coef_goal 1.0 \
    --coef_qp 2.0 \
    --log_interval 10

# %%
python visualize.py --checkpoint affine_swarm_checkpoint.pt --seed 3
